# %%
#Q.1
#Stress When depth is constant
Q = float(input("Enter the value of Load in kN: "))
N = int(input("Number of data values of radial distance: "))
pi = 3.14159265359
Z = float(input("Depth: "))
r = []

for i in range(1, N + 1):
    print("Enter radial distance in m for data point {}".format(i))
    Value_r = float(input())
    r.append(Value_r)

for i in range(N):
    Stress = (3 * Q) / (2 * pi * Z * Z) * ((1 / (1 + ((r[i] / Z) ** 2))) ** 1.5)
    print("Stress at radial distance {} m: {} kN/m^2".format(r[i], Stress))
# Out:
# Enter the value of Load in kN: 2500
# Number of data values of radial distance: 5
# Depth: 6
# Enter radial distance in m for data point 1
# 1
# Enter radial distance in m for data point 2
# 2
# Enter radial distance in m for data point 3
# 3
# Enter radial distance in m for data point 4
# 4
# Enter radial distance in m for data point 5
# 5
# Stress at radial distance 1.0 m: 31.82218962439578 kN/m^2
# Stress at radial distance 2.0 m: 28.31018180877209 kN/m^2
# Stress at radial distance 3.0 m: 23.725418113904343 kN/m^2
# Stress at radial distance 4.0 m: 19.099747679556568 kN/m^2
# Stress at radial distance 5.0 m: 15.03273123397073 kN/m^2

# %%
#Q.2
Q = float(input("Enter the value of Load in kN: "))
M = int(input("Number of data values of depth: "))
pi = 3.14159265359
r = float(input("Radial Distance: "))
Z = []

for j in range(1, M + 1):
    print("Enter depth in z for data point {}".format(j))
    Value_Z = float(input())
    Z.append(Value_Z)
    Stress = (3 * Q) / (2 * pi * r * r * Value_Z) * ((1 / (1 + ((r / Value_Z) ** 2))) ** 2.5)
    print("Stress at depth {} m: {} kN/m^2".format(Value_Z, Stress))
# Out:
# Enter the value of Load in kN: 2500
# Number of data values of depth: 6
# Radial Distance: 5
# Enter depth in z for data point 1
# 1
# Stress at depth 1.0 m: 0.013851857541709211 kN/m^2
# Enter depth in z for data point 2
# 2
# Stress at depth 2.0 m: 0.16868108050414463 kN/m^2
# Enter depth in z for data point 3
# 3
# Stress at depth 3.0 m: 0.5737584737684108 kN/m^2
# Enter depth in z for data point 4
# 4
# Stress at depth 4.0 m: 1.1355903932608502 kN/m^2
# Enter depth in z for data point 5
# 5
# Stress at depth 5.0 m: 1.688093092794463 kN/m^2
# Enter depth in z for data point 6
# 6
# Stress at depth 6.0 m: 2.1292261944509363 kN/m^2

# %%
#Q.3
# Calculating the stress by Boussineq's Theory
Q= int(input("Enter the value of given load :"))
z= int(input("Enter the distance of vertical stress :"))
r= int(input("Enter the distance ofhorizntal stress:"))
stress = ((3*Q*(1/(1+(r/z)**2)) **2.5))/(2%3.14*(z**2))
print("The value of stress is", stress)
# Out:
# Enter the value of given load :2500
# Enter the distance of vertical stress :6
# Enter the distance ofhorizntal stress:5
# The value of stress is 27.87150570966022
